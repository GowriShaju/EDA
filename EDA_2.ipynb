# %% [markdown]
# #**Bangluru House Price Data**
#
#
# In 2017, housing units sold in India dropped by 7% due to demonetization, RERA enforcement, and reduced trust in developers. Bengaluru's property prices fell by nearly 5% in the second half of the year. Various housing options were available, with many apartments priced between ₹42-62 lakh, making home buying complex, especially in cities like Bengaluru.

# %% [markdown]
# ##About the dataset
#
# area_type: This categorical variable describes the type of area, such as "Super built-up Area" or "Plot Area." Different area types may have different price implications.
#
# availability: A categorical variable that indicates when the property will be available, either a specific date or "Ready To Move." Properties ready for immediate possession may have higher or lower prices depending on demand.
#
# location: A categorical variable representing the locality of the property. Location is one of the most important factors in determining property prices.
#
# size: A categorical variable that indicates the size of the property, often described by the number of bedrooms (e.g., "2 BHK" or "4 Bedroom"). Larger homes tend to have higher prices.
#
# society: A categorical variable representing the housing society the property belongs to. Properties in well-known or premium societies may have higher prices. Many missing values in this column may need to be handled.
#
# total_sqft: A mix of numeric and non-numeric values representing the total area of the property in square feet. This variable usually has a direct impact on price, as larger homes are typically more expensive.
#
# bath: A numeric variable indicating the number of bathrooms. More bathrooms often correlate with larger, more expensive homes.
#
# balcony: A numeric variable indicating the number of balconies. Like bathrooms, this can influence price, as more balconies may imply better amenities and larger space.

# %% [markdown]
# #Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #1 - Loading and Understanding the data

# %%
data = pd.read_csv("Bengaluru_House_Data.csv")
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# ##Head and Tail

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
data.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.tail(10)
# Out:
#                   area_type   availability               location       size  \
# 13310  Super built-up  Area  Ready To Move           Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move       Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move              Bellandur      2 BHK
# 13313  Super built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price
# 13310      NaN       1050   2.0      2.0   52.71
# ...

# %% [markdown]
# ##Dimension

# %%
data.shape
# Out:
# (13320, 9)

# %% [markdown]
# ##Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %% [markdown]
# ##Columns or features

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %% [markdown]
# ##value counts of categorical data

# %%
data['availability'].value_counts()
# Out:
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Oct               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64

# %%
data['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %%
data['location'].value_counts()
# Out:
# location
# Whitefield                         540
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# Name: count, Length: 1305, dtype: int64

# %%
data['society'].value_counts()
# Out:
# society
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# SLtalry     1
# Rencyes     1
# DiaveEn     1
# Suiumy      1
# Amionce     1
# Name: count, Length: 2688, dtype: int64

# %%
data['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %% [markdown]
# #**2 - Cleaning of the data**

# %% [markdown]
# ##checking for missing values

# %%
missing = data.isnull().sum()
missing
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# Here society has the highest number of null values

# %% [markdown]
# ##Droping columns

# %%
#dopping society column because it has te highest number of null values
data.drop(columns = ['society'], inplace = True)
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price
# 0          2 BHK       1056   2.0      1.0   39.07
# ...

# %%
#dropping total_sqrt because it is complicated
data.drop(columns = ['total_sqft'], inplace = True)
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  bath  balcony   price
# 0          2 BHK   2.0      1.0   39.07
# 1      4 Bedroom   5.0      3.0  120.00
# ...

# %% [markdown]
# ##Filling missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   bath          13247 non-null  float64
#  5   balcony       12711 non-null  float64
#  6   price         13320 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 728.6+ KB

# %% [markdown]
# ###For Categorical Columns
#
# We use mode to fill the categorical values

# %%
data['location'].fillna(data['location'].mode()[0], inplace = True)  #to take the first mode value as mode, we use index.
                                                                      #Then the filling is projected in the info
data['size'].fillna(data['size'].mode()[0], inplace = True)
# Out:
# /tmp/ipython-input-1193121157.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['location'].fillna(data['location'].mode()[0], inplace = True)  #to take the first mode value as mode, we use index.
# /tmp/ipython-input-1193121157.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ###For Numerical Columns
#
# For numerical columns, we plot histograms to decide which measure to use to fill the null values.

# %%
#plotting histogram to see if the data is skewed
sns.histplot(x = data['bath'], kde = True, bins = 30)
plt.show()

# %% [markdown]
# It shows that the data is skewed. So we use median to fill the null values

# %%
data['bath'].fillna(data['bath'].median(), inplace = True)
# Out:
# /tmp/ipython-input-1517591324.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bath'].fillna(data['bath'].median(), inplace = True)

# %%
#For balcony
sns.histplot(x = data['balcony'], kde = True, bins = 30)
plt.show()

# %% [markdown]
# The plot shows that the data is normally distributed. So we use mean to fill the missing values.

# %%
data['balcony'].fillna(data['balcony'].mean(), inplace = True)
# Out:
# /tmp/ipython-input-1534979821.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['balcony'].fillna(data['balcony'].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   bath          13320 non-null  float64
#  5   balcony       13320 non-null  float64
#  6   price         13320 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 728.6+ KB

# %% [markdown]
# ##Changing data types

# %% [markdown]
# ###float to int

# %%
data['bath'] = data['bath'].astype(int)
data['balcony'] = data['balcony'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   bath          13320 non-null  int64
#  5   balcony       13320 non-null  int64
#  6   price         13320 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 728.6+ KB

# %% [markdown]
# ##Removing duplicates

# %%
data.drop_duplicates(inplace = True)
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  bath  balcony   price
# 0          2 BHK     2        1   39.07
# 1      4 Bedroom     5        3  120.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12248 entries, 0 to 13318
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12248 non-null  object
#  1   availability  12248 non-null  object
#  2   location      12248 non-null  object
#  3   size          12248 non-null  object
#  4   bath          12248 non-null  int64
#  5   balcony       12248 non-null  int64
#  6   price         12248 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 765.5+ KB

# %% [markdown]
# #**3 - Descriptive statistics**

# %%
data.describe()
# Out:
#                bath       balcony         price
# count  12248.000000  12248.000000  12248.000000
# mean       2.721587      1.549967    115.907577
# std        1.375004      0.819529    154.139312
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     74.000000
# 75%        3.000000      2.000000    125.000000
# max       40.000000      3.000000   3600.000000

# %%
data.describe(include = 'all')
# Out:
#                    area_type   availability    location   size          bath  \
# count                  12248          12248       12248  12248  12248.000000
# unique                     4             81        1305     31           NaN
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK           NaN
# freq                    7826           9656         474   4638           NaN
# mean                     NaN            NaN         NaN    NaN      2.721587
# std                      NaN            NaN         NaN    NaN      1.375004
# min                      NaN            NaN         NaN    NaN      1.000000
# 25%                      NaN            NaN         NaN    NaN      2.000000
# 50%                      NaN            NaN         NaN    NaN      2.000000
# 75%                      NaN            NaN         NaN    NaN      3.000000
# max                      NaN            NaN         NaN    NaN     40.000000
#
#              balcony         price
# ...

# %%
data.hist(bins = 30, color = 'navy')
plt.show()

# %% [markdown]
# #**4 - Data Visualization**

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  bath  balcony   price
# 0          2 BHK     2        1   39.07
# 1      4 Bedroom     5        3  120.00
# ...

# %%
sns.histplot(data['bath'], kde = True, bins = 30)
plt.show()

# %%
sns.histplot(data['price'], kde = True, bins = 30)
plt.show()

# %%
sns.pairplot(data[['bath','size', 'price']], hue = 'size')
plt.show()

# %%
sns.countplot(data['size'], color = 'navy')
plt.show()

# %%
sns.countplot(data['area_type'])
plt.show()

# %% [markdown]
# #**5 - Correlation Analysis**

# %% [markdown]
# ##Relation Analysis

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  bath  balcony   price
# 0          2 BHK     2        1   39.07
# 1      4 Bedroom     5        3  120.00
# ...

# %%
data['size'].value_counts()
# Out:
# size
# 2 BHK         4638
# 3 BHK         3927
# 4 Bedroom      820
# 4 BHK          565
# 3 Bedroom      534
# 1 BHK          499
# 2 Bedroom      311
# 5 Bedroom      290
# 6 Bedroom      191
# 1 Bedroom      103
# 8 Bedroom       84
# 7 Bedroom       82
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 10 BHK           2
# 11 Bedroom       2
# 27 BHK           1
# 19 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 14 BHK           1
# 12 Bedroom       1
# 13 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
#Converting the size feature to three other

import pandas as pd

def split_features(value):
  if 'BHK' in value:
    bedroom = int(value.split()[0]) #to get the number before BHK in the size column.
    hall = 1
    kitchen = 2

  elif 'Bedroom' in value:
    bedroom = int(value.split()[0])
    hall = 0
    kitchen = 0

  elif value == '1 RK':
    bedroom = 1
    hall = 0
    kitchen = 0

  else:
    bedroom = None
    hall = None
    kitchen = None
  return bedroom, hall, kitchen


#apply the function
data[['bedroom', 'hall', 'kitchen']] = data['size'].apply(lambda x: pd.Series(split_features(x)))
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  bath  balcony   price  bedroom  hall  kitchen
# 0          2 BHK     2        1   39.07        2     1        2
# ...

# %%
#dropping the size column
data.drop('size', axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
lab_enco = LabelEncoder()
data['location'] = lab_enco.fit_transform(data['location'])
data['availability'] = lab_enco.fit_transform(data['availability'])

data['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    7826
# Built-up  Area          2354
# Plot  Area              1981
# Carpet  Area              87
# Name: count, dtype: int64

# %%
#replacing the catrgoriecal values in area_type with numbers
data["area_type"].replace(["Plot  Area","Carpet  Area","Built-up  Area","Super built-up  Area"],[0,1,2,3],inplace=True)
# Out:
# /tmp/ipython-input-3291357581.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["area_type"].replace(["Plot  Area","Carpet  Area","Built-up  Area","Super built-up  Area"],[0,1,2,3],inplace=True)
# /tmp/ipython-input-3291357581.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data
# Out:
#        area_type  availability  location  bath  balcony   price  bedroom  \
# 0              3            40       419     2        1   39.07        2
# 1              0            80       317     5        3  120.00        4
# 2              2            80      1179     2        3   62.00        3
# 3              3            80       757     3        1   95.00        3
# 4              3            80       716     2        1   51.00        2
# ...          ...           ...       ...   ...      ...     ...      ...
# 13314          3            80       474     3        3  112.00        3
# 13315          2            80      1252     4        0  231.00        5
# 13316          3            80      1004     5        1  400.00        4
# 13317          2            80       972     2        1   60.00        2
# 13318          3            32       907     4        1  488.00        4
#
#        hall  kitchen
# 0         1        2
# 1         0        0
# 2         1        2
# ...

# %% [markdown]
# ##Correlation Matrix

# %%
corr_mat = data.corr()
corr_mat
# Out:
#               area_type  availability  location      bath   balcony     price  \
# area_type      1.000000     -0.125599  0.010009 -0.371990  0.124050 -0.258212
# availability  -0.125599      1.000000 -0.007805  0.072703  0.094319  0.036987
# location       0.010009     -0.007805  1.000000  0.005929  0.000058  0.014787
# bath          -0.371990      0.072703  0.005929  1.000000  0.137848  0.447888
# balcony        0.124050      0.094319  0.000058  0.137848  1.000000  0.070775
# price         -0.258212      0.036987  0.014787  0.447888  0.070775  1.000000
# bedroom       -0.403752      0.095430 -0.004615  0.896636  0.128510  0.391277
# hall           0.869215     -0.108754 -0.001520 -0.427166  0.140831 -0.293987
# kitchen        0.869215     -0.108754 -0.001520 -0.427166  0.140831 -0.293987
#
#                bedroom      hall   kitchen
# area_type    -0.403752  0.869215  0.869215
# availability  0.095430 -0.108754 -0.108754
# location     -0.004615 -0.001520 -0.001520
# ...

# %%
sns.heatmap(corr_mat, annot = True, fmt = '.1f', cmap = 'Blues')
plt.show()

# %% [markdown]
# ###Correlation matrix of one feature to others

# %%
price_corr = data.corr()['price']
price_corr

sns.heatmap(price_corr.to_frame(), annot = True, fmt = '.2f', cmap = 'Blues', annot_kws={'size': 10})
plt.show()

# %%
#dropping less correlated ones
data.drop('availability', axis = 1, inplace = True)
data.drop('location', axis = 1, inplace = True)

# %% [markdown]
# ##Skewness detection

# %% [markdown]
# ###Bedroom

# %%
sns.histplot(data['bedroom'], bins = 30,kde = True)
plt.show()

# %% [markdown]
# ###Hall

# %%
sns.histplot(data['hall'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ###Kitchen

# %%
sns.histplot(data['kitchen'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ###Area_type

# %%
data['area_type'] = np.log1p(data['area_type'])
sns.histplot(data['area_type'], bins = 30, kde = True)
plt.show()

# %% [markdown]
# #**6 - Outlier Detection**

# %% [markdown]
# ##Bedroom

# %%
#boxplot for visual representation
sns.boxplot(data['bedroom'])
plt.show()

print()
print()

from scipy import stats
z_sco = np.abs(stats.zscore(data['bedroom']))
outliers = data[z_sco > 3]
print(f'The number of outlier is {outliers.shape[0]}')
# Out:
# The number of outlier is 268

# %% [markdown]
# ##kitchen

# %%
sns.boxplot(data['kitchen'])
plt.show()

z_scok = np.abs(stats.zscore(data['kitchen']))
outliers_k = data[z_scok > 3]
print(f'The number of outliers in kitchen is {outliers_k.shape[0]}')
# Out:
# The number of outliers in kitchen is 0

# %% [markdown]
# ##Hall

# %%
sns.boxplot(data['hall'])
plt.show()

z_scoh = np.abs(stats.zscore(data['hall']))
outliers_h = data [z_scoh > 3]
print(f'The number of outliers in hall is {outliers_h.shape[0]}')
# Out:
# The number of outliers in hall is 0

# %% [markdown]
# ##area_type

# %%
sns.boxplot(data['area_type'])
plt.show()

z_scoa = np.abs(stats.zscore(data['area_type']))
outliers_a = data [z_scoa > 3]
print(f'The number of outliers in area_type is {outliers_a.shape[0]}')
# Out:
# The number of outliers in area_type is 0

# %% [markdown]
# ##Bath

# %%
sns.boxplot(data['bath'])
plt.show()

z_scoba = np.abs(stats.zscore(data['bath']))
outliers_ba = data [z_scoba > 3]
print(f'The number of outliers in bath is {outliers_ba.shape[0]}')
# Out:
# The number of outliers in bath is 241

# %% [markdown]
# ##balcony

# %%
sns.boxplot(data['balcony'])
plt.show()

z_scobal = np.abs(stats.zscore(data['balcony']))
outliers_bal = data [z_scobal > 3]
print(f'The number of outliers in balcony is {outliers_bal.shape[0]}')
# Out:
# The number of outliers in balcony is 0

# %% [markdown]
# ##Checking and removing outliers

# %%
data
# Out:
#        area_type  bath  balcony   price  bedroom  hall  kitchen
# 0       1.386294     2        1   39.07        2     1        2
# 1       0.000000     5        3  120.00        4     0        0
# 2       1.098612     2        3   62.00        3     1        2
# 3       1.386294     3        1   95.00        3     1        2
# 4       1.386294     2        1   51.00        2     1        2
# ...          ...   ...      ...     ...      ...   ...      ...
# 13314   1.386294     3        3  112.00        3     1        2
# 13315   1.098612     4        0  231.00        5     0        0
# 13316   1.386294     5        1  400.00        4     1        2
# 13317   1.098612     2        1   60.00        2     1        2
# 13318   1.386294     4        1  488.00        4     1        2
#
# [12248 rows x 7 columns]

# %%
data.shape
# Out:
# (12248, 7)

# %%
data.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ###Function to remove ouliers

# %%
def remove_outliers(data, exclude_columns):
  for col in data.columns:
    #skip the specified column
    if col == exclude_columns:
      continue
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)

    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    # Filter the DataFrame to remove rows with outliers in each column
    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
  return data


#calling the function
data_cleaned = remove_outliers(data, exclude_columns = 'price')
data_cleaned
# Out:
#        area_type  bath  balcony   price  bedroom  hall  kitchen
# 0       1.386294     2        1   39.07        2     1        2
# 2       1.098612     2        3   62.00        3     1        2
# 3       1.386294     3        1   95.00        3     1        2
# 4       1.386294     2        1   51.00        2     1        2
# 5       1.386294     2        1   38.00        2     1        2
# ...          ...   ...      ...     ...      ...   ...      ...
# 13310   1.386294     2        2   52.71        2     1        2
# 13312   1.386294     2        2   47.00        2     1        2
# 13314   1.386294     3        3  112.00        3     1        2
# 13317   1.098612     2        1   60.00        2     1        2
# 13318   1.386294     4        1  488.00        4     1        2
#
# [9390 rows x 7 columns]

# %%
data = data_cleaned
data.shape
# Out:
# (9390, 7)

# %% [markdown]
# #**7 - Feature Engineering**

# %% [markdown]
# We already did feature engineering during correlation analysis by splitting the feature, size

# %% [markdown]
# #**8 - Dimensionality Reduction**

# %%
from sklearn.preprocessing import StandardScaler
features = ['bedroom', 'bath', 'balcony']
x = StandardScaler().fit_transform(data[features])

#pcs
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca_result = pca.fit_transform(x)

#components
data['pc1'] = pca_result[:,0]
data['pc2'] = pca_result[:,1]

#visualizing the result
sns.scatterplot(x = data['pc1'], y = data['pc2'], hue = data['price'])
plt.show()

# %% [markdown]
# #**9 - Data Scaling**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

features = ['bedroom', 'bath', 'balcony']
scaler_mm = MinMaxScaler().fit_transform(data[features])

# %% [markdown]
# #**10 - Modelling and testing hypothesis**

# %%
from sklearn.model_selection import train_test_split
x = data[['bedroom', 'bath', 'balcony']]
y = data['price']
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)


#Modelling
from sklearn.linear_model import LinearRegression
model = LinearRegression()

#fitting
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

#metrics
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(f"MSE: {mse}, RMSE: {rmse}, R-squared: {r2}")
# Out:
# MSE: 4273.117647162297, RMSE: 65.36908785628187, R-squared: 0.2869454755611702
